# %%
import pandas as  pd

# %%
df=pd.read_csv("daiict_faculty_data.csv")
df
# Out:
#                        Name  \
# 0            Abhishek gupta
# 1           Abhishek jindal
# 2            Abhishek tilva
# 3               Aditya tatu
# 4              Ajay beniwal
# ..                      ...
# 107        Vishvajit pandya
# 108              Ajay tomar
# 109     Anirban dutta gupta
# 110  Harpreet singh jattana
# 111             K c supekar
#
#                                            Profile URL  \
# 0      https://www.daiict.ac.in/faculty/abhishek-gupta
# 1     https://www.daiict.ac.in/faculty/abhishek-jindal
# 2      https://www.daiict.ac.in/faculty/abhishek-tilva
# 3         https://www.daiict.ac.in/faculty/aditya-tatu
# 4        https://www.daiict.ac.in/faculty/ajay-beniwal
# ..                                                 ...
# 107  https://www.daiict.ac.in/distinguished-profess...
# 108  https://www.daiict.ac.in/professor-practice/aj...
# 109  https://www.daiict.ac.in/professor-practice/an...
# 110  https://www.daiict.ac.in/professor-practice/ha...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                112 non-null    object
#  1   Profile URL         112 non-null    object
#  2   Qualification       110 non-null    object
#  3   Phone               79 non-null     object
#  4   Address             77 non-null     object
#  5   Email               111 non-null    object
#  6   Specialization      109 non-null    object
#  7   Image URL           112 non-null    object
#  8   Biography           69 non-null     object
#  9   Research Interests  109 non-null    object
#  10  Teaching            60 non-null     object
#  11  Publications        70 non-null     object
# dtypes: object(12)
# memory usage: 10.6+ KB

# %%
df1=pd.read_csv("dau_faculty.csv")
df1
# Out:
#     faculty_id                    Name  \
# 0        F-001          Abhishek gupta
# 1        F-002         Abhishek jindal
# 2        F-003          Abhishek tilva
# 3        F-004             Aditya tatu
# 4        F-005            Ajay beniwal
# ..         ...                     ...
# 104      F-105        Vishvajit pandya
# 105      F-106              Ajay tomar
# 106      F-107     Anirban dutta gupta
# 107      F-108  Harpreet singh jattana
# 108      F-109             K c supekar
#
#                                            Profile URL  \
# 0      https://www.daiict.ac.in/faculty/abhishek-gupta
# 1     https://www.daiict.ac.in/faculty/abhishek-jindal
# 2      https://www.daiict.ac.in/faculty/abhishek-tilva
# 3         https://www.daiict.ac.in/faculty/aditya-tatu
# 4        https://www.daiict.ac.in/faculty/ajay-beniwal
# ..                                                 ...
# 104  https://www.daiict.ac.in/distinguished-profess...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   faculty_id          109 non-null    object
#  1   Name                109 non-null    object
#  2   Profile URL         109 non-null    object
#  3   Qualification       107 non-null    object
#  4   Phone               78 non-null     object
#  5   Address             76 non-null     object
#  6   Email               108 non-null    object
#  7   Specialization      109 non-null    object
#  8   Image URL           109 non-null    object
#  9   Biography           68 non-null     object
#  10  Research Interests  109 non-null    object
#  11  Teaching            60 non-null     object
#  12  Publications        69 non-null     object
# dtypes: object(13)
# memory usage: 11.2+ KB
